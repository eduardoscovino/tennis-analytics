# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data/charting-m-points-from-2017-enriched.csv' , encoding= 'unicode_escape', low_memory=False)

# %%
df.head()
# Out:
#                                             match_id  Pt  Set1  Set2  Gm1
# 0  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   1     0     0    0  \
# 1  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   2     0     0    0
# 2  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   3     0     0    0
# 3  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   4     0     0    0
# 4  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   5     0     0    0
#
#    Gm2    Pts    Gm# TbSet TB?  ...  PtWinner  isSvrWinner  rallyCount
# 0    0    0-0  1 (1)     1   0  ...         2            0           0  \
# 1    0   0-15  1 (2)     1   0  ...         1            1           1
# 2    0  15-15  1 (3)     1   0  ...         2            0           2
# 3    0  15-30  1 (4)     1   0  ...         1            1           1
# 4    0  30-30  1 (5)     1   0  ...         1            1           1
#
#        Date        Tournament Round Surface     Player 1             Player 2
# ...

# %%
df['Marin Cilic Result'] = pd.Series(pd.NA)
df_player1 = df[df['Player 1'].str.contains("Marin Cilic")]
df_player2 = df[df['Player 2'].str.contains("Marin Cilic")]

# %%
df_player2.head()
# Out:
#                                               match_id  Pt  Set1  Set2  Gm1
# 8087  20221002-M-Tel_Aviv-F-Novak_Djokovic-Marin_Cilic   1     0     0    0  \
# 8088  20221002-M-Tel_Aviv-F-Novak_Djokovic-Marin_Cilic   2     0     0    0
# 8089  20221002-M-Tel_Aviv-F-Novak_Djokovic-Marin_Cilic   3     0     0    0
# 8090  20221002-M-Tel_Aviv-F-Novak_Djokovic-Marin_Cilic   4     0     0    0
# 8091  20221002-M-Tel_Aviv-F-Novak_Djokovic-Marin_Cilic   5     0     0    0
#
#       Gm2    Pts    Gm# TbSet TB?  ...  isSvrWinner  rallyCount      Date
# 8087    0    0-0  1 (1)     1   0  ...            1           5  20221002  \
# 8088    0   15-0  1 (2)     1   0  ...            0           0  20221002
# 8089    0  15-15  1 (3)     1   0  ...            0           8  20221002
# 8090    0  15-30  1 (4)     1   0  ...            1           1  20221002
# 8091    0  30-30  1 (5)     1   0  ...            1           1  20221002
#
# ...

# %%
df_player1.loc[df_player1['PtWinner'] == 1, 'Marin Cilic Result'] = 1
df_player1.loc[df_player1['PtWinner'] == 2, 'Marin Cilic Result'] = 0

# %%
df_player2.loc[df_player2['PtWinner'] == 2, 'Marin Cilic Result'] = 1
df_player2.loc[df_player2['PtWinner'] == 1, 'Marin Cilic Result'] = 0

# %%
df_final = pd.concat([df_player1,df_player2])

# %%
df_final.size
# Out:
# 273448
