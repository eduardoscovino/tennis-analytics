# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw_data/charting-m-points-from-2017-enriched.csv', encoding= 'unicode_escape')
df.head()
# Out:
# /tmp/ipykernel_968/1650028709.py:1: DtypeWarning: Columns (8,9,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('raw_data/charting-m-points-from-2017-enriched.csv', encoding= 'unicode_escape')
#                                             match_id  Pt  Set1  Set2  Gm1
# 0  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   1     0     0    0  \
# 1  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   2     0     0    0
# 2  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   3     0     0    0
# 3  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   4     0     0    0
# 4  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   5     0     0    0
#
#    Gm2    Pts    Gm# TbSet TB?  ...  PtWinner  isSvrWinner  rallyCount
# 0    0    0-0  1 (1)     1   0  ...         2            0           0  \
# 1    0   0-15  1 (2)     1   0  ...         1            1           1
# ...

# %%
meaning_char = pd.read_csv('https://raw.githubusercontent.com/eduardoscovino/tennis-analytics/master/code_map.csv',
                           encoding= 'unicode_escape', sep=';')
meaning_char
# Out:
#    code                                               info           remark
# 0     4                                               wide  serve direction
# 1     5                                               body  serve direction
# 2     6                                         down the T  serve direction
# 3     f                                           forehand      common shot
# 4     b                                           backhand      common shot
# 5     s                                     backhand slice      common shot
# 6     r                                     forehand slice      common shot
# 7     @                                     unforced error  how point ended
# 8     #                                       forced error  how point ended
# 9     *                                             winner  how point ended
# 10    n                                                net    type of error
# ...

# %%
print(df.columns)
# Out:
# Index(['match_id', 'Pt', 'Set1', 'Set2', 'Gm1', 'Gm2', 'Pts', 'Gm#', 'TbSet',
#        'TB?', 'TBpt', 'Svr', 'Ret', 'Serving', '1st', '2nd', 'Notes', '1stSV',
#        '2ndSV', '1stIn', '2ndIn', 'isAce', 'isUnret', 'isRallyWinner',
#        'isForced', 'isUnforced', 'isDouble', 'PtWinner', 'isSvrWinner',
#        'rallyCount', 'Date', 'Tournament', 'Round', 'Surface', 'Player 1',
#        'Player 2', 'Grand Slam'],
#       dtype='object')

# %%
df[['1st', '2nd']].head(25)
# Out:
#                1st                                                2nd
# 0               4d                                                 5n
# 1               4#                                                NaN
# 2               4n                                           5f29f3n#
# 3            6f3x#                                                NaN
# 4               4#                                                NaN
# 5               6w                                                 4x
# 6               4*                                                NaN
# 7               6d                                                 4d
# 8               4w                   6b27f38b27f38b38b39b38b39b38f1d@
# 9               6n                                     4b39f19f28f38*
# 10              4w                         6b18f38b38b39b38f38s18f39*
# 11              4n                               4b38b28f17f19f29f1n@
# ...

# %%
#Spliting Serve and Return
df['RETURN'] = df.loc[:, '2nd']
df['RETURN'].fillna(df.loc[:, '1st'], inplace=True)


df['Serve'] = df.loc[:, 'RETURN'].str[0:1]

df['RETURN'] = df['RETURN'].str[1:]

df.head()
# Out:
#                                             match_id  Pt  Set1  Set2  Gm1
# 0  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   1     0     0    0  \
# 1  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   2     0     0    0
# 2  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   3     0     0    0
# 3  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   4     0     0    0
# 4  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   5     0     0    0
#
#    Gm2    Pts    Gm# TbSet TB?  ...  rallyCount      Date        Tournament
# 0    0    0-0  1 (1)     1   0  ...           0  20221123  Davis Cup Finals  \
# 1    0   0-15  1 (2)     1   0  ...           1  20221123  Davis Cup Finals
# 2    0  15-15  1 (3)     1   0  ...           2  20221123  Davis Cup Finals
# 3    0  15-30  1 (4)     1   0  ...           1  20221123  Davis Cup Finals
# 4    0  30-30  1 (5)     1   0  ...           1  20221123  Davis Cup Finals
#
# ...

# %%
#Spliting every shot
df['RETURN'] = df['RETURN'].apply(lambda x: ''.join([c for c in x if c not in sc]))
df['RETURN'] = df['RETURN'].str.replace('f',' f').str.replace('b',' b').str.replace('s',' s').str.replace('r',' r')
df['RETURN'] = df['RETURN'].map(lambda x: x.lstrip(' ').rstrip(' '))

# %%
df.head()
# Out:
#                                             match_id  Pt  Set1  Set2  Gm1
# 0  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   1     0     0    0  \
# 1  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   2     0     0    0
# 2  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   3     0     0    0
# 3  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   4     0     0    0
# 4  20221123-M-Davis_Cup_Finals-QF-Marin_Cilic-Pab...   5     0     0    0
#
#    Gm2    Pts    Gm# TbSet TB?  ...  rallyCount      Date        Tournament
# 0    0    0-0  1 (1)     1   0  ...           0  20221123  Davis Cup Finals  \
# 1    0   0-15  1 (2)     1   0  ...           1  20221123  Davis Cup Finals
# 2    0  15-15  1 (3)     1   0  ...           2  20221123  Davis Cup Finals
# 3    0  15-30  1 (4)     1   0  ...           1  20221123  Davis Cup Finals
# 4    0  30-30  1 (5)     1   0  ...           1  20221123  Davis Cup Finals
#
# ...
